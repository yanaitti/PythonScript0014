# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

import lightgbm as lgb
from optuna.integration import lightgbm as lgb_optuna

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split, GridSearchCV,StratifiedKFold,cross_validate
from sklearn.metrics import roc_auc_score
from sklearn.metrics import mean_absolute_error
from sklearn.impute import SimpleImputer

# %%
# !dir
# Out:
#  ドライブ D のボリューム ラベルがありません。
#  ボリューム シリアル番号は 3417-05D0 です
#
#  D:\PythonTraining\IPO のディレクトリ
#
# 2020/09/24  18:56    <DIR>          .
# 2020/09/24  18:56    <DIR>          ..
# 2020/09/24  14:06    <DIR>          .ipynb_checkpoints
# 2020/09/13  15:07           711,599 analyze_20200912.ipynb
# 2020/09/22  19:24           472,855 analyze_20200920.ipynb
# 2020/09/24  18:56         1,118,227 analyze_20200924.ipynb
# 2020/09/12  11:06    <DIR>          bk
# 2020/09/24  18:26            30,119 ipo_data_download.ipynb
# 2020/09/23  14:48           871,004 list.txt
# 2020/09/23  15:49        22,383,974 list2.txt
# 2020/09/23  15:51             2,545 test_20200923.csv
# 2020/09/24  18:08             4,208 test_20200924.csv
# 2020/09/23  15:51           636,985 train_20200923.csv
# 2020/09/24  18:08           636,985 train_20200924.csv
#               10 個のファイル          26,868,501 バイト
#                4 個のディレクトリ  958,192,418,816 バイトの空き領域

# %%
train = pd.read_csv('train_20200924.csv')
test = pd.read_csv('test_20200924.csv')

# %%
train
# Out:
#                 name        date  code market_name         market_key  \
# 0         株式会社雪国まいたけ  2020/09/17  1375        東証１部      ＳＭＢＣ日興証券、大和証券
# 1     株式会社インターファクトリー  2020/08/25  4057        マザーズ     ＳＭＢＣ日興証券、SBI証券
# 2      ニューラルポケット株式会社  2020/08/20  4056        マザーズ              みずほ証券
# 3        ティアンドエス株式会社  2020/08/07  4055        マザーズ             いちよし証券
# 4           株式会社モダリス  2020/08/03  4883        マザーズ              みずほ証券
# ...              ...         ...   ...         ...                ...
# 2145          マックハウス  1999/02/10  7603          ＪＱ               野村證券
# 2146             ポプラ  1999/02/05  7601          ＪＱ               野村證券
# 2147            船井電機  1999/02/04  6839        大証２部           大和証券エスビー
# 2148        ニッコウトラベル  1999/02/02  9373          ＪＱ               野村證券
# 2149        イトーヨーギョー  1999/01/29  5287        大証２部  日興ソロモン・スミス・バーニー証券
#
#         v_kobo  kessan           p_kari  p_uri                       bb  \
# 0     20323500       3  2,000円 - 2,400円   2200  2020/09/02 - 2020/09/08
# 1      1110900       5      870円 - 960円    960  2020/08/07 - 2020/08/14
# 2       630800      12      800円 - 900円    900  2020/08/04 - 2020/08/11
# 3       277000      11  2,650円 - 2,800円   2800  2020/07/20 - 2020/07/28
# 4      3105000      12  1,000円 - 1,200円   1200  2020/07/14 - 2020/07/20
# ...        ...     ...              ...    ...                      ...
# 2145   1400000       2  1,000円 - 1,000円   1200  1999/01/25 - 1999/01/28
# 2146   1300000       2  1,000円 - 1,000円   1200  1999/01/20 - 1999/01/25
# 2147   2000000       6  3,800円 - 3,800円   4800  1999/01/19 - 1999/01/22
# 2148    800000       3      500円 - 500円    560  1999/01/14 - 1999/01/20
# 2149    700000       3      800円 - 800円    950  1999/01/13 - 1999/01/25
#
#       koutou                                            content    gyosyu  \
# 0      -4.55               まいたけ、エリンギ、ぶなしめじ等の生産販売及びきのこの加工食品の製造販売    水産・農林業
# 1     429.17                                クラウド型ECプラットフォーム構築事業    情報・通信業
# 2     466.67  AIエンジニアリング事業（独自開発のAIアルゴリズムによる画像・動画解析技術とエッジコンピュ...    情報・通信業
# 3     150.36      大手企業及び半導体工場向けシステム開発・運用保守・インフラ構築、AI関連のソフトウエア開発    情報・通信業
# 4     110.00  コアとなるプラットフォーム技術である『切らないCRISPR技術（CRISPR-GNDM技術）...       医薬品
# ...      ...                                                ...       ...
# 2145   16.66                      ジーンズを中心としたアメリカンカジュアルウエア専門店の経営       小売業
# 2146   72.50                    フランチャイズチェーンシステムによるコンビニエンスストアの経営       小売業
# 2147  100.00                               映像機器を中心とした電気製品の製造販売等      電気機器
# 2148  101.78                               熟年層を対象とした海外旅行の企画及び販売  倉庫・運輸関連業
# 2149   36.84  バイコンマンホール、バイコンパイプ、景観製品等の製造・販売及び下水道関連分野での商品、周辺技...  ガラス・土石製品
#
#       v_tani     d_uri  d_stocked   d_capital
# 0        100  17672700   39850000   100000000
# 1        100    500000    3220000   116400000
# 2        100    133600   13369000   100000000
# 3        100     77000    1580700    74120000
# 4        100    600000   25100000  1300000000
# ...      ...       ...        ...         ...
# 2145    1000    650000    8500000  1235350000
# 2146    1000    300000    5191900   739737735
# 2147     100    500000    9646000   482532000
# 2148    1000    400000    3500000   183750000
# 2149    1000    350000    3218000   250800000
#
# [2150 rows x 17 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2150 entries, 0 to 2149
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         2150 non-null   object
#  1   date         2150 non-null   object
#  2   code         2150 non-null   int64
#  3   market_name  2150 non-null   object
#  4   market_key   2150 non-null   object
#  5   v_kobo       2150 non-null   int64
#  6   kessan       2150 non-null   int64
#  7   p_kari       2150 non-null   object
#  8   p_uri        2150 non-null   int64
#  9   bb           2150 non-null   object
#  10  koutou       2150 non-null   float64
#  11  content      2150 non-null   object
#  12  gyosyu       2150 non-null   object
#  13  v_tani       2150 non-null   int64
#  14  d_uri        2150 non-null   int64
#  15  d_stocked    2150 non-null   int64
#  16  d_capital    2150 non-null   int64
# dtypes: float64(1), int64(8), object(8)
# memory usage: 285.7+ KB

# %%
train[train['koutou'] >= 0]['koutou'].plot.hist()
plt.show()

train[train['koutou'] >= 0]['koutou'].plot.box()
plt.show()

train[train['koutou'] >= 0]['koutou'].describe()
# Out:
# count    1809.000000
# mean       88.670315
# std       106.195548
# min         0.000000
# 25%        15.000000
# 50%        53.840000
# 75%       125.000000
# max       988.890000
# Name: koutou, dtype: float64

# %%
def decide_y(x):
    if x < 50:
        return 0
    else:
        return 1
#     if x < 0:
#         return 0
#     elif x >= 15.0:
#         return 1
#     elif x >= 53.84:
#         return 2
#     elif x >= 125.0:
#         return 3
#     else:
#         return 4

# %%
train['y'] = train['koutou'].apply(decide_y)
train[['koutou', 'y']]
# Out:
#       koutou  y
# 0      -4.55  0
# 1     429.17  1
# 2     466.67  1
# 3     150.36  1
# 4     110.00  1
# ...      ... ..
# 2145   16.66  0
# 2146   72.50  1
# 2147  100.00  1
# 2148  101.78  1
# 2149   36.84  0
#
# [2150 rows x 2 columns]

# %%
all_df = pd.concat([train, test], axis=0).reset_index(drop=True)

# %%
all_df
# Out:
#                     name        date  code market_name      market_key  \
# 0             株式会社雪国まいたけ  2020/09/17  1375        東証１部   ＳＭＢＣ日興証券、大和証券
# 1         株式会社インターファクトリー  2020/08/25  4057        マザーズ  ＳＭＢＣ日興証券、SBI証券
# 2          ニューラルポケット株式会社  2020/08/20  4056        マザーズ           みずほ証券
# 3            ティアンドエス株式会社  2020/08/07  4055        マザーズ          いちよし証券
# 4               株式会社モダリス  2020/08/03  4883        マザーズ           みずほ証券
# ...                  ...         ...   ...         ...             ...
# 2158  株式会社STIフードホールディングス  2020/09/25  2932        東証２部            野村證券
# 2159            株式会社I-ne  2020/09/25  4933        マザーズ        ＳＭＢＣ日興証券
# 2160            トヨクモ株式会社  2020/09/24  4058        マザーズ          いちよし証券
# 2161            株式会社まぐまぐ  2020/09/24  4059         JQS           SBI証券
# 2162           株式会社グラフィコ  2020/09/24  4930         JQS           SBI証券
#
#         v_kobo  kessan           p_kari p_uri                       bb  \
# 0     20323500       3  2,000円 - 2,400円  2200  2020/09/02 - 2020/09/08
# 1      1110900       5      870円 - 960円   960  2020/08/07 - 2020/08/14
# 2       630800      12      800円 - 900円   900  2020/08/04 - 2020/08/11
# 3       277000      11  2,650円 - 2,800円  2800  2020/07/20 - 2020/07/28
# 4      3105000      12  1,000円 - 1,200円  1200  2020/07/14 - 2020/07/20
# ...        ...     ...              ...   ...                      ...
# 2158   1495500      12  1,790円 - 1,900円  1900  2020/09/07 - 2020/09/11
# 2159   2463300      12  2,580円 - 2,890円  2890  2020/09/08 - 2020/09/14
# 2160    550000      12  1,800円 - 2,000円  2000  2020/09/04 - 2020/09/10
# 2161    680000       9      730円 - 810円   810  2020/09/07 - 2020/09/11
# 2162    322000       6  3,850円 - 4,090円  4090  2020/09/04 - 2020/09/10
#
#       koutou                                            content  gyosyu  \
# 0      -4.55               まいたけ、エリンギ、ぶなしめじ等の生産販売及びきのこの加工食品の製造販売  水産・農林業
# 1     429.17                                クラウド型ECプラットフォーム構築事業  情報・通信業
# 2     466.67  AIエンジニアリング事業（独自開発のAIアルゴリズムによる画像・動画解析技術とエッジコンピュ...  情報・通信業
# 3     150.36      大手企業及び半導体工場向けシステム開発・運用保守・インフラ構築、AI関連のソフトウエア開発  情報・通信業
# 4     110.00  コアとなるプラットフォーム技術である『切らないCRISPR技術（CRISPR-GNDM技術）...     医薬品
# ...      ...                                                ...     ...
# 2158     NaN                  水産原料素材の調達から製造・販売までを一貫して行う食品製造販売事業     食料品
# 2159     NaN                  ヘアケア製品、美容家電、化粧品及び健康食品関連のファブレスメーかー      化学
# 2160     NaN      法人向けクラウドサービス事業（安否確認サービス及びKintone連携サービスの開発・販売）  情報・通信業
# 2161     NaN  コンテンツ配信プラットフォームの運営を行うプラットフォーム事業、Webメディアの運営等を行う...  情報・通信業
# 2162     NaN                          健康食品・化粧品・日用雑貨・医薬品等の企画製造販売      化学
#
#       v_tani     d_uri  d_stocked   d_capital    y
# 0        100  17672700   39850000   100000000  0.0
# 1        100    500000    3220000   116400000  1.0
# 2        100    133600   13369000   100000000  1.0
# 3        100     77000    1580700    74120000  1.0
# 4        100    600000   25100000  1300000000  1.0
# ...      ...       ...        ...         ...  ...
# 2158     100   1000000    5000500   100000000  NaN
# 2159     100    428400    6600000   475000000  NaN
# 2160     100    200000    4702000    57300000  NaN
# 2161     100    120000    2200000   100000000  NaN
# 2162     100    200000     800000    10000000  NaN
#
# [2163 rows x 18 columns]

# %%
all_df = all_df.drop('koutou', axis=1)

# %%
all_df['y'] = all_df['y'].fillna(-999)

# %%
all_df['year'] = all_df['date'].apply(lambda x: x.split('/')[0]).astype('int')
all_df['month'] = all_df['date'].apply(lambda x: x.split('/')[1]).astype('int')
all_df['day'] = all_df['date'].apply(lambda x: x.split('/')[2]).astype('int')
all_df
# Out:
#                     name        date  code market_name      market_key  \
# 0             株式会社雪国まいたけ  2020/09/17  1375        東証１部   ＳＭＢＣ日興証券、大和証券
# 1         株式会社インターファクトリー  2020/08/25  4057        マザーズ  ＳＭＢＣ日興証券、SBI証券
# 2          ニューラルポケット株式会社  2020/08/20  4056        マザーズ           みずほ証券
# 3            ティアンドエス株式会社  2020/08/07  4055        マザーズ          いちよし証券
# 4               株式会社モダリス  2020/08/03  4883        マザーズ           みずほ証券
# ...                  ...         ...   ...         ...             ...
# 2158  株式会社STIフードホールディングス  2020/09/25  2932        東証２部            野村證券
# 2159            株式会社I-ne  2020/09/25  4933        マザーズ        ＳＭＢＣ日興証券
# 2160            トヨクモ株式会社  2020/09/24  4058        マザーズ          いちよし証券
# 2161            株式会社まぐまぐ  2020/09/24  4059         JQS           SBI証券
# 2162           株式会社グラフィコ  2020/09/24  4930         JQS           SBI証券
#
#         v_kobo  kessan           p_kari p_uri                       bb  \
# 0     20323500       3  2,000円 - 2,400円  2200  2020/09/02 - 2020/09/08
# 1      1110900       5      870円 - 960円   960  2020/08/07 - 2020/08/14
# 2       630800      12      800円 - 900円   900  2020/08/04 - 2020/08/11
# 3       277000      11  2,650円 - 2,800円  2800  2020/07/20 - 2020/07/28
# 4      3105000      12  1,000円 - 1,200円  1200  2020/07/14 - 2020/07/20
# ...        ...     ...              ...   ...                      ...
# 2158   1495500      12  1,790円 - 1,900円  1900  2020/09/07 - 2020/09/11
# 2159   2463300      12  2,580円 - 2,890円  2890  2020/09/08 - 2020/09/14
# 2160    550000      12  1,800円 - 2,000円  2000  2020/09/04 - 2020/09/10
# 2161    680000       9      730円 - 810円   810  2020/09/07 - 2020/09/11
# 2162    322000       6  3,850円 - 4,090円  4090  2020/09/04 - 2020/09/10
#
#                                                 content  gyosyu  v_tani  \
# 0                  まいたけ、エリンギ、ぶなしめじ等の生産販売及びきのこの加工食品の製造販売  水産・農林業     100
# 1                                   クラウド型ECプラットフォーム構築事業  情報・通信業     100
# 2     AIエンジニアリング事業（独自開発のAIアルゴリズムによる画像・動画解析技術とエッジコンピュ...  情報・通信業     100
# 3         大手企業及び半導体工場向けシステム開発・運用保守・インフラ構築、AI関連のソフトウエア開発  情報・通信業     100
# 4     コアとなるプラットフォーム技術である『切らないCRISPR技術（CRISPR-GNDM技術）...     医薬品     100
# ...                                                 ...     ...     ...
# 2158                  水産原料素材の調達から製造・販売までを一貫して行う食品製造販売事業     食料品     100
# 2159                  ヘアケア製品、美容家電、化粧品及び健康食品関連のファブレスメーかー      化学     100
# 2160      法人向けクラウドサービス事業（安否確認サービス及びKintone連携サービスの開発・販売）  情報・通信業     100
# 2161  コンテンツ配信プラットフォームの運営を行うプラットフォーム事業、Webメディアの運営等を行う...  情報・通信業     100
# 2162                          健康食品・化粧品・日用雑貨・医薬品等の企画製造販売      化学     100
#
#          d_uri  d_stocked   d_capital      y  year  month  day
# 0     17672700   39850000   100000000    0.0  2020      9   17
# 1       500000    3220000   116400000    1.0  2020      8   25
# 2       133600   13369000   100000000    1.0  2020      8   20
# 3        77000    1580700    74120000    1.0  2020      8    7
# 4       600000   25100000  1300000000    1.0  2020      8    3
# ...        ...        ...         ...    ...   ...    ...  ...
# 2158   1000000    5000500   100000000 -999.0  2020      9   25
# 2159    428400    6600000   475000000 -999.0  2020      9   25
# 2160    200000    4702000    57300000 -999.0  2020      9   24
# 2161    120000    2200000   100000000 -999.0  2020      9   24
# 2162    200000     800000    10000000 -999.0  2020      9   24
#
# [2163 rows x 20 columns]

# %%
all_df.hist( figsize=(14, 10), bins=20)
# Out:
# array([[<AxesSubplot:title={'center':'code'}>,
#         <AxesSubplot:title={'center':'v_kobo'}>,
#         <AxesSubplot:title={'center':'kessan'}>],
#        [<AxesSubplot:title={'center':'v_tani'}>,
#         <AxesSubplot:title={'center':'d_uri'}>,
#         <AxesSubplot:title={'center':'d_stocked'}>],
#        [<AxesSubplot:title={'center':'d_capital'}>,
#         <AxesSubplot:title={'center':'y'}>,
#         <AxesSubplot:title={'center':'year'}>],
#        [<AxesSubplot:title={'center':'month'}>,
#         <AxesSubplot:title={'center':'day'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
all_df.describe()
# Out:
#               code        v_kobo       kessan       v_tani         d_uri  \
# count  2163.000000  2.163000e+03  2163.000000  2163.000000  2.163000e+03
# mean   4865.237171  3.810100e+06     5.551549   219.641701  2.609398e+06
# std    2159.292055  4.303520e+07     3.538803   355.538807  3.888937e+07
# min    1375.000000  5.000000e+02     1.000000     1.000000  0.000000e+00
# 25%    3178.500000  5.725000e+03     3.000000     1.000000  8.900000e+02
# 50%    4307.000000  5.175000e+05     3.000000   100.000000  1.100000e+05
# 75%    6615.500000  1.289450e+06     9.000000   100.000000  5.000000e+05
# max    9551.000000  1.764063e+09    12.000000  1000.000000  1.603694e+09
#
#           d_stocked     d_capital            y         year        month  \
# count  2.163000e+03  2.163000e+03  2163.000000  2163.000000  2163.000000
# mean   1.543622e+07  5.431538e+09    -5.562182  2007.548313     7.293574
# std    1.789215e+08  1.081125e+11    77.268500     6.519653     3.528042
# min    0.000000e+00  0.000000e+00  -999.000000  1999.000000     1.000000
# 25%    2.752800e+04  1.499590e+08     0.000000  2002.000000     4.000000
# 50%    2.000000e+06  3.165710e+08     0.000000  2006.000000     7.000000
# 75%    5.633182e+06  6.469500e+08     1.000000  2014.000000    10.500000
# max    4.787145e+09  3.500000e+12     1.000000  2020.000000    12.000000
#
#                day
# count  2163.000000
# mean     16.848821
# std       8.179744
# min       1.000000
# 25%      10.000000
# 50%      18.000000
# 75%      24.000000
# max      31.000000

# %%
all_df.corr()['y'].abs().sort_values(ascending=False)[1:]
# Out:
# year         0.147671
# kessan       0.097119
# month        0.046588
# v_tani       0.024967
# day          0.023265
# d_stocked    0.013051
# v_kobo       0.008279
# d_uri        0.007031
# code         0.004254
# d_capital    0.002900
# Name: y, dtype: float64

# %%
all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2163 entries, 0 to 2162
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         2163 non-null   object
#  1   date         2163 non-null   object
#  2   code         2163 non-null   int64
#  3   market_name  2163 non-null   object
#  4   market_key   2163 non-null   object
#  5   v_kobo       2163 non-null   int64
#  6   kessan       2163 non-null   int64
#  7   p_kari       2163 non-null   object
#  8   p_uri        2163 non-null   object
#  9   bb           2163 non-null   object
#  10  content      2163 non-null   object
#  11  gyosyu       2163 non-null   object
#  12  v_tani       2163 non-null   int64
#  13  d_uri        2163 non-null   int64
#  14  d_stocked    2163 non-null   int64
#  15  d_capital    2163 non-null   int64
#  16  y            2163 non-null   float64
#  17  year         2163 non-null   int32
#  18  month        2163 non-null   int32
#  19  day          2163 non-null   int32
# dtypes: float64(1), int32(3), int64(7), object(9)
# memory usage: 312.7+ KB

# %%
categorical_features = ['market_name', 'market_key', 'kessan', 'gyosyu', 'v_tani']

# %%
all_df = all_df.drop(['name', 'date', 'code', 'p_kari', 'p_uri', 'bb', 'content'], axis=1)

# %%
for col in categorical_features:
    lbl = LabelEncoder()
    lbl.fit(all_df[col])
    lbl.transform(all_df[col])
    all_df[col] = lbl.transform(all_df[col])

# %%
all_df
# Out:
#       market_name  market_key    v_kobo  kessan  gyosyu  v_tani     d_uri  \
# 0              14          98  20323500       2      15       2  17672700
# 1               6          95   1110900       4      13       2    500000
# 2               6          10    630800      11      13       2    133600
# 3               6           6    277000      10      13       2     77000
# 4               6          10   3105000      11       9       2    600000
# ...           ...         ...       ...     ...     ...     ...       ...
# 2158           15          72   1495500      11      30       2   1000000
# 2159            6          94   2463300      11       8       2    428400
# 2160            6           6    550000      11      13       2    200000
# 2161            1           4    680000       8      13       2    120000
# 2162            1           4    322000       5       8       2    200000
#
#       d_stocked   d_capital      y  year  month  day
# 0      39850000   100000000    0.0  2020      9   17
# 1       3220000   116400000    1.0  2020      8   25
# 2      13369000   100000000    1.0  2020      8   20
# 3       1580700    74120000    1.0  2020      8    7
# 4      25100000  1300000000    1.0  2020      8    3
# ...         ...         ...    ...   ...    ...  ...
# 2158    5000500   100000000 -999.0  2020      9   25
# 2159    6600000   475000000 -999.0  2020      9   25
# 2160    4702000    57300000 -999.0  2020      9   24
# 2161    2200000   100000000 -999.0  2020      9   24
# 2162     800000    10000000 -999.0  2020      9   24
#
# [2163 rows x 13 columns]

# %%
#訓練データ、テストデータの分割
train_df = all_df[all_df["y"] != -999.0]
test_df = all_df[all_df["y"] == -999.0]

# %%
y_train = train_df['y']
X_train = train_df.drop(['y'], axis=1)
X_test = test_df.drop(['y'], axis=1)

# %%
y_train.shape, X_train.shape, X_test.shape
# Out:
# ((2150,), (2150, 12), (13, 12))

# %%
# 訓練データからデータを分割
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.3, random_state=0, stratify=y_train)

# %%
# 使用モデルはLGB（パラメータチューニング無）
lgb_train = lgb.Dataset(X_train, y_train, categorical_feature=categorical_features)
lgb_eval = lgb.Dataset(X_valid, y_valid, reference=lgb_train, categorical_feature=categorical_features)

params = {
    'objective': 'binary'
#     'objective': 'multiclass', 
#     'num_class': 5,
}

model = lgb.train(
    params, lgb_train,
    valid_sets=[lgb_train, lgb_eval],
    verbose_eval=10,
    num_boost_round=1000,
    early_stopping_rounds=10
)

y_pred = model.predict(X_test, num_iteration=model.best_iteration)
# Out:
# D:\anaconda3\lib\site-packages\lightgbm\basic.py:1551: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# [LightGBM] [Info] Number of positive: 669, number of negative: 836
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000543 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1193
# [LightGBM] [Info] Number of data points in the train set: 1505, number of used features: 12
# D:\anaconda3\lib\site-packages\lightgbm\basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# D:\anaconda3\lib\site-packages\lightgbm\basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.444518 -> initscore=-0.222845
# [LightGBM] [Info] Start training from score -0.222845
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.473993	valid_1's binary_logloss: 0.55415
# [20]	training's binary_logloss: 0.377475	valid_1's binary_logloss: 0.534881
# [30]	training's binary_logloss: 0.311271	valid_1's binary_logloss: 0.535694
# Early stopping, best iteration is:
# [23]	training's binary_logloss: 0.353954	valid_1's binary_logloss: 0.532527

# %%
y_pred
# Out:
# array([0.45187511, 0.76068626, 0.05664243, 0.10140892, 0.67376367,
#        0.86470454, 0.90510216, 0.72355163, 0.10281643, 0.3694346 ,
#        0.92508545, 0.82018213, 0.49684618])

# %%
X_test
# Out:
#       market_name  market_key    v_kobo  kessan  gyosyu  v_tani     d_uri  \
# 2150            1          10    306000       6      11       2    251000
# 2151            6          72   2500000      11      13       2         0
# 2152           13          31  87631400       2      28       2  66068900
# 2153           13          11   7845900      11       3       2   7845900
# 2154            6           4    300000       8       5       2         0
# 2155            6          94    595700      11      13       2    440000
# 2156            6          10    115000      11      13       2         0
# 2157            6          10   1524900      11      13       2   1059600
# 2158           15          72   1495500      11      30       2   1000000
# 2159            6          94   2463300      11       8       2    428400
# 2160            6           6    550000      11      13       2    200000
# 2161            1           4    680000       8      13       2    120000
# 2162            1           4    322000       5       8       2    200000
#
#       d_stocked    d_capital  year  month  day
# 2150    2995500     87250000  2020     10   16
# 2151    7545000    131800000  2020     10   13
# 2152  517500000  10000000000  2020     10    6
# 2153   20050500   1600000000  2020     10    5
# 2154    5000000    920000000  2020     10    2
# 2155    2000000     50000000  2020      9   30
# 2156     822800    243866000  2020      9   29
# 2157    5026500     99000000  2020      9   28
# 2158    5000500    100000000  2020      9   25
# 2159    6600000    475000000  2020      9   25
# 2160    4702000     57300000  2020      9   24
# 2161    2200000    100000000  2020      9   24
# 2162     800000     10000000  2020      9   24

# %%
def build():
    kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

    lgb_train = lgb_optuna.Dataset(X_train, y_train)

    lgbm_params = {
        'objective': 'binary',
        'metric': 'binary_logloss',
#         'objective': 'multiclass',
#         'metric': 'multi_logloss',
#         'num_class': 5,
        'random_state':0,
        'verbosity': 0
    }

    tunecv = lgb_optuna.LightGBMTunerCV(
        lgbm_params,
        lgb_train,
        num_boost_round=100,
        early_stopping_rounds=20,
        seed = 0,
        verbose_eval=20,
        folds=kf
    )

    tunecv.run()

    print( 'Best score = ',tunecv.best_score)
    print( 'Best params= ',tunecv.best_params)

    return tunecv

tunecv = build()
# Out:
# [I 2020-09-24 18:57:38,618] A new study created in memory with name: no-name-b96a4d9c-ffab-4f28-aa79-6127dfc78695
# feature_fraction, val_score: inf:   0%|                                                          | 0/7 [00:00<?, ?it/s]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000390 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000394 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000407 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000462 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000354 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [20]	cv_agg's binary_logloss: 0.526767 + 0.0127095
# [40]	cv_agg's binary_logloss: 0.522084 + 0.012565
# feature_fraction, val_score: 0.519126:  14%|######4                                      | 1/7 [00:00<00:01,  3.34it/s][I 2020-09-24 18:57:38,925] Trial 0 finished with value: 0.5191261138817076 and parameters: {'feature_fraction': 1.0}. Best is trial 0 with value: 0.5191261138817076.
# feature_fraction, val_score: 0.519126:  14%|######4                                      | 1/7 [00:00<00:01,  3.34it/s]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000374 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000272 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000410 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000299 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000461 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [20]	cv_agg's binary_logloss: 0.517533 + 0.0107048
# [40]	cv_agg's binary_logloss: 0.498659 + 0.0134619
# [60]	cv_agg's binary_logloss: 0.501971 + 0.0200029
# feature_fraction, val_score: 0.496157:  29%|############8                                | 2/7 [00:00<00:01,  3.19it/s][I 2020-09-24 18:57:39,272] Trial 1 finished with value: 0.4961567839395335 and parameters: {'feature_fraction': 0.5}. Best is trial 1 with value: 0.4961567839395335.
# feature_fraction, val_score: 0.496157:  29%|############8                                | 2/7 [00:00<00:01,  3.19it/s]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000374 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000352 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000272 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000163 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000303 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [20]	cv_agg's binary_logloss: 0.524687 + 0.0121033
# [40]	cv_agg's binary_logloss: 0.51235 + 0.0175876
# [60]	cv_agg's binary_logloss: 0.521053 + 0.0178953
# feature_fraction, val_score: 0.496157:  43%|###################2                         | 3/7 [00:01<00:01,  3.06it/s][I 2020-09-24 18:57:39,631] Trial 2 finished with value: 0.510575030748883 and parameters: {'feature_fraction': 0.7}. Best is trial 1 with value: 0.4961567839395335.
# feature_fraction, val_score: 0.496157:  43%|###################2                         | 3/7 [00:01<00:01,  3.06it/s]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000357 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000241 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000261 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000339 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000342 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [20]	cv_agg's binary_logloss: 0.519549 + 0.00861758
# [40]	cv_agg's binary_logloss: 0.503236 + 0.0155236
# [60]	cv_agg's binary_logloss: 0.509779 + 0.0205022
# feature_fraction, val_score: 0.496157:  57%|#########################7                   | 4/7 [00:01<00:00,  3.05it/s][I 2020-09-24 18:57:39,962] Trial 3 finished with value: 0.5025776445720458 and parameters: {'feature_fraction': 0.4}. Best is trial 1 with value: 0.4961567839395335.
# feature_fraction, val_score: 0.496157:  57%|#########################7                   | 4/7 [00:01<00:00,  3.05it/s]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000475 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000253 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000270 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000263 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000387 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [20]	cv_agg's binary_logloss: 0.52431 + 0.0109137
# [40]	cv_agg's binary_logloss: 0.505201 + 0.0162054
# [60]	cv_agg's binary_logloss: 0.514017 + 0.0233893
# feature_fraction, val_score: 0.496157:  71%|################################1            | 5/7 [00:01<00:00,  3.06it/s][I 2020-09-24 18:57:40,287] Trial 4 finished with value: 0.5031514231855034 and parameters: {'feature_fraction': 0.6}. Best is trial 1 with value: 0.4961567839395335.
# feature_fraction, val_score: 0.496157:  71%|################################1            | 5/7 [00:01<00:00,  3.06it/s]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000380 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000309 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000249 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000265 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000374 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [20]	cv_agg's binary_logloss: 0.522766 + 0.00862291
# [40]	cv_agg's binary_logloss: 0.514512 + 0.0145064
# feature_fraction, val_score: 0.496157:  86%|######################################5      | 6/7 [00:01<00:00,  3.13it/s][I 2020-09-24 18:57:40,588] Trial 5 finished with value: 0.5122486141342059 and parameters: {'feature_fraction': 0.8}. Best is trial 1 with value: 0.4961567839395335.
# feature_fraction, val_score: 0.496157:  86%|######################################5      | 6/7 [00:01<00:00,  3.13it/s]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000426 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000351 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000373 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000346 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000384 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [20]	cv_agg's binary_logloss: 0.529131 + 0.0126589
# [40]	cv_agg's binary_logloss: 0.523562 + 0.0211419
# [60]	cv_agg's binary_logloss: 0.533034 + 0.0250341
# feature_fraction, val_score: 0.496157: 100%|#############################################| 7/7 [00:02<00:00,  3.08it/s][I 2020-09-24 18:57:40,923] Trial 6 finished with value: 0.5210058769884132 and parameters: {'feature_fraction': 0.8999999999999999}. Best is trial 1 with value: 0.4961567839395335.
# feature_fraction, val_score: 0.496157: 100%|#############################################| 7/7 [00:02<00:00,  3.04it/s]
# num_leaves, val_score: 0.496157:   0%|                                                          | 0/20 [00:00<?, ?it/s]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000453 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000239 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000309 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000422 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000395 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	cv_agg's binary_logloss: 0.517762 + 0.0136529
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [40]	cv_agg's binary_logloss: 0.499523 + 0.0232577
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# num_leaves, val_score: 0.496157:   5%|##5                                               | 1/20 [00:01<00:22,  1.17s/it][I 2020-09-24 18:57:42,104] Trial 7 finished with value: 0.498363090971219 and parameters: {'num_leaves': 56}. Best is trial 7 with value: 0.498363090971219.
# num_leaves, val_score: 0.496157:   5%|##5                                               | 1/20 [00:01<00:22,  1.17s/it]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000344 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000330 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000261 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000315 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000416 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [20]	cv_agg's binary_logloss: 0.519293 + 0.0125704
# [40]	cv_agg's binary_logloss: 0.49986 + 0.0165559
# [60]	cv_agg's binary_logloss: 0.504579 + 0.0229803
# num_leaves, val_score: 0.496157:  10%|#####                                             | 2/20 [00:01<00:16,  1.07it/s][I 2020-09-24 18:57:42,480] Trial 8 finished with value: 0.4978246487152128 and parameters: {'num_leaves': 27}. Best is trial 8 with value: 0.4978246487152128.
# num_leaves, val_score: 0.496157:  10%|#####                                             | 2/20 [00:01<00:16,  1.07it/s]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000392 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000432 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000369 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000393 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000358 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	cv_agg's binary_logloss: 0.517762 + 0.0136529
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [60]	cv_agg's binary_logloss: 0.519764 + 0.0129527
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [80]	cv_agg's binary_logloss: 0.519088 + 0.0160759
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# min_data_in_leaf, val_score: 0.492575: 100%|#############################################| 5/5 [00:04<00:00,  1.09it/s][I 2020-09-24 18:58:18,088] Trial 67 finished with value: 0.5180123771582698 and parameters: {'min_child_samples': 100}. Best is trial 65 with value: 0.49346301481438176.
# min_data_in_leaf, val_score: 0.492575: 100%|#############################################| 5/5 [00:04<00:00,  1.23it/s]
# Best score =  0.4925751490405498
# Best params=  {'objective': 'binary', 'metric': 'binary_logloss', 'random_state': 0, 'verbosity': 0, 'feature_pre_filter': False, 'lambda_l1': 7.718736811082202e-05, 'lambda_l2': 0.00014944691328502082, 'num_leaves': 31, 'feature_fraction': 0.5, 'bagging_fraction': 0.9729618913045325, 'bagging_freq': 4, 'min_child_samples': 20}

# %%
# train_data = lgb.Dataset( X_train, y_train )
# eval_data = lgb.Dataset(X_valid, label=X_valid, reference= train_data)

lgb_train = lgb.Dataset(X_train, y_train, categorical_feature=categorical_features)
lgb_eval = lgb.Dataset(X_valid, y_valid, reference=lgb_train, categorical_feature=categorical_features)

clf = lgb.train( tunecv.best_params, 
                lgb_train,
                valid_sets=lgb_eval,
                num_boost_round=50,
                verbose_eval=0
               )
y_pred = clf.predict( X_valid )
# print('AUC: ', roc_auc_score(y_valid, y_pred))
# Out:
# D:\anaconda3\lib\site-packages\lightgbm\basic.py:1551: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000318 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# D:\anaconda3\lib\site-packages\lightgbm\basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# D:\anaconda3\lib\site-packages\lightgbm\basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))

# %%
clf.predict( X_test )
# Out:
# array([0.20951752, 0.81666677, 0.01517654, 0.06578988, 0.79462186,
#        0.81109189, 0.90902627, 0.76548724, 0.09113998, 0.37818177,
#        0.94723489, 0.72295663, 0.49928176])

# %%
test
# Out:
#                     name        date  code market_name  \
# 0         株式会社アースインフィニティ  2020/10/16  7692         JQS
# 1             日通システム株式会社  2020/10/13  4013        マザーズ
# 2      キオクシアホールディングス株式会社  2020/10/06  6600          東証
# 3   株式会社ダイレクトマーケティングミックス  2020/10/05  7354          東証
# 4                株式会社タスキ  2020/10/02  2987        マザーズ
# 5               株式会社アクシス  2020/09/30  4012        マザーズ
# 6          株式会社ヘッドウォータース  2020/09/29  4011        マザーズ
# 7             rakumo株式会社  2020/09/28  4060        マザーズ
# 8     株式会社STIフードホールディングス  2020/09/25  2932        東証２部
# 9               株式会社I-ne  2020/09/25  4933        マザーズ
# 10              トヨクモ株式会社  2020/09/24  4058        マザーズ
# 11              株式会社まぐまぐ  2020/09/24  4059         JQS
# 12             株式会社グラフィコ  2020/09/24  4930         JQS
#
#                                            market_key    v_kobo  kessan  \
# 0                                               みずほ証券    306000       7
# 1                                                野村證券   2500000      12
# 2   三菱ＵＦＪモルガン・スタンレー証券、野村證券、ゴールドマン・サックス証券、J.Ｐ.モルガン証...  87631400       3
# 3                                      みずほ証券、ＳＭＢＣ日興証券   7845900      12
# 4                                               SBI証券    300000       9
# 5                                            ＳＭＢＣ日興証券    595700      12
# 6                                               みずほ証券    115000      12
# 7                                               みずほ証券   1524900      12
# 8                                                野村證券   1495500      12
# 9                                            ＳＭＢＣ日興証券   2463300      12
# 10                                             いちよし証券    550000      12
# 11                                              SBI証券    680000       9
# 12                                              SBI証券    322000       6
#
#              p_kari      p_uri                       bb  \
# 0        2020/09/28  2020/10/0  2020/09/30 - 2020/10/06
# 1        2020/09/23  2020/10/0  2020/09/25 - 2020/10/01
# 2   2,800円 - 3,500円  2020/09/2  2020/09/18 - 2020/09/25
# 3   2,400円 - 2,980円  2020/09/2  2020/09/16 - 2020/09/24
# 4       610円 - 670円  2020/09/2  2020/09/14 - 2020/09/18
# 5   1,020円 - 1,070円       1070  2020/09/11 - 2020/09/17
# 6   2,240円 - 2,400円       2400  2020/09/09 - 2020/09/15
# 7   1,100円 - 1,250円       1250  2020/09/08 - 2020/09/14
# 8   1,790円 - 1,900円       1900  2020/09/07 - 2020/09/11
# 9   2,580円 - 2,890円       2890  2020/09/08 - 2020/09/14
# 10  1,800円 - 2,000円       2000  2020/09/04 - 2020/09/10
# 11      730円 - 810円        810  2020/09/07 - 2020/09/11
# 12  3,850円 - 4,090円       4090  2020/09/04 - 2020/09/10
#
#                                               content  gyosyu  v_tani  \
# 0                         小売電気事業、ガス小売事業、電子機器の製造・販売・卸業     小売業     100
# 1        統合HRMソリューションの開発・販売・サポートまでの一貫したソリューションサービスの提供  情報・通信業     100
# 2       メモリ及びSSD等関連製品の開発・製造・販売事業等を営むグループ会社の経営戦略策定及び管理    電気機器     100
# 3                    ダイレクトマーケティングを通じた営業ソリューションサービスの提供   サービス業     100
# 4                   新築投資用IoTレジデンスの企画、開発、販売及びコンサルティング等    不動産業     100
# 5   業務アプリケーションの設計開発・運用保守、インフラシステムの設計構築・運用保守の提供及びクラ...  情報・通信業     100
# 6   AIソリューション事業（企業の経営課題をITやAIのシステム開発を通して解決するソリューショ...  情報・通信業     100
# 7                   企業向けクラウド型グループウェア製品「rakumo」の開発・販売等  情報・通信業     100
# 8                   水産原料素材の調達から製造・販売までを一貫して行う食品製造販売事業     食料品     100
# 9                   ヘアケア製品、美容家電、化粧品及び健康食品関連のファブレスメーかー      化学     100
# 10      法人向けクラウドサービス事業（安否確認サービス及びKintone連携サービスの開発・販売）  情報・通信業     100
# 11  コンテンツ配信プラットフォームの運営を行うプラットフォーム事業、Webメディアの運営等を行う...  情報・通信業     100
# 12                          健康食品・化粧品・日用雑貨・医薬品等の企画製造販売      化学     100
#
#        d_uri  d_stocked    d_capital
# 0     251000    2995500     87250000
# 1          0    7545000    131800000
# 2   66068900  517500000  10000000000
# 3    7845900   20050500   1600000000
# 4          0    5000000    920000000
# 5     440000    2000000     50000000
# 6          0     822800    243866000
# 7    1059600    5026500     99000000
# 8    1000000    5000500    100000000
# 9     428400    6600000    475000000
# 10    200000    4702000     57300000
# 11    120000    2200000    100000000
# 12    200000     800000     10000000
